# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedita-rajesh/BasalGanglia/blob/main/DQN_BGsystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy as np
import tensorflow as tf
from google.colab import drive
import joblib

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class BasalGangliaMDP(gym.Env):
    def __init__(self):
        super().__init__()

        # Define states
        self.states = ['Cortex', 'Striatum', 'GPe', 'STN', 'GPi', 'Thalamus']

        # Define actions
        self.actions = ["activation", "inhibition"]
        self.action_space = gym.spaces.Discrete(len(self.actions))

        self.transition_probs = {
            "Cortex": {
                "activation": { "Striatum": 1.0 },
                "inhibition": { "Striatum": 1.0 }
            },
            "Striatum": {
                "inhibition": { 'GPe': 0.5, 'GPi': 0.5 },
            },
            "GPe": {
                "inhibition": { "STN": 1.0 },
            },
            "STN": {
                "activation": { "GPi": 1.0 },
            },
            "GPi": {
                "inhibition": { "Thalamus": 1.0 },
            },
            "Thalamus": {
                "activation": { "Cortex": 1.0 },
            }
        }

        self.rewards = {
            ("Cortex", "activation", "Striatum") : 1.0,
            ("Cortex", "inhibition", "Striatum") : 1.0,

            ("Striatum", "inhibition", "GPe") : 1.0,
            ("Striatum", "inhibition", "GPi") : 1.0,

            ("GPe", "inhibition", "STN") : 1.0,

            ("STN", "activation", "GPi") : 1.0,

            ("GPi", "inhibition", "Thalamus") : 1.0,

            ("Thalamus", "activation", "Cortex") : 1.0
        }

        self.state = 'Cortex'  # Initial state

    def calculate_rewards(self, state, action, next_state, dopamine, acetyl, levodopa):
          if(dopamine <= 39.6 and acetyl > 2.5 and levodopa < 100):
            if(state == "Cortex" and next_state == "Striatum"):
              if(action == "activation"):
                return self.rewards.get((self.state, action, next_state), 0) * -100
              elif(action == "inhibition"):
                return self.rewards.get((self.state, action, next_state), 0) * 250

            elif(state=="Striatum" and next_state=="GPe"):
                return self.rewards.get((self.state, action, next_state), 0) * 400

            elif(state=="Striatum" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * -250

            elif(state=="GPe" and next_state=="STN"):
                return self.rewards.get((self.state, action, next_state), 0) * 500

            elif(state=="STN" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * 600

            elif(state=="GPi" and next_state=="Thalamus"):
                return self.rewards.get((self.state, action, next_state), 0) * 800

            else:
                raise Exception("Get good bro")


          elif(dopamine <= 39.6 and acetyl > 2.5 and levodopa >= 100 and levodopa <=250):
            if(state == "Cortex" and next_state == "Striatum"):
              if(action == "activation"):
                return self.rewards.get((self.state, action, next_state), 0) * 200

              elif(action == "inhibition"):
                return self.rewards.get((self.state, action, next_state), 0) * -150

            elif(state=="Striatum" and next_state=="GPe"):
                return self.rewards.get((self.state, action, next_state), 0) * -200

            elif(state=="Striatum" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * 450

            elif(state=="GPe" and next_state=="STN"):
                return self.rewards.get((self.state, action, next_state), 0) * -300

            elif(state=="STN" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * -350

            elif(state=="GPi" and next_state=="Thalamus"):
                return self.rewards.get((self.state, action, next_state), 0) * 1000

            else:
                raise Exception("Get good bro")


          elif(dopamine > 39.6 and dopamine <= 195.8 and acetyl >=0.5 and acetyl <= 2.5):
            if(state == "Cortex" and next_state == "Striatum"):
              if(action == "activation"):
                return self.rewards.get((self.state, action, next_state), 0) * 200

              elif(action == "inhibition"):
                return self.rewards.get((self.state, action, next_state), 0) * -150

            elif(state=="Striatum" and next_state=="GPe"):
                return self.rewards.get((self.state, action, next_state), 0) * -200

            elif(state=="Striatum" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * 550

            elif(state=="GPe" and next_state=="STN"):
                return self.rewards.get((self.state, action, next_state), 0) * -300

            elif(state=="STN" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * -350

            elif(state=="GPi" and next_state=="Thalamus"):
                return self.rewards.get((self.state, action, next_state), 0) * 1000

            else:
                raise Exception("Get good bro")


    def step(self, action, dopamine, acetyl, levodopa):

        next_state_probs = self.transition_probs[self.state][action]
        next_state = np.random.choice(list(next_state_probs.keys()), p=list(next_state_probs.values()))

        # reward = self.rewards.get((self.state, action, next_state), 0)

        reward = self.calculate_rewards(self.state, action, next_state, dopamine, acetyl, levodopa)

        self.state = next_state

        done = next_state == 'Thalamus'  # Terminal state
        info = {}

        return next_state, reward, done, info

    def reset(self):
        self.state = 'Cortex'
        return self.state

    def render(self):
        print(self.state)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class DQNAgent:
    def __init__(self, state_space_size, action_space_size, learning_rate=0.001, discount_factor=0.9, exploration_prob=0.9):
        self.state_space_size = state_space_size
        self.action_space_size = action_space_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_prob = exploration_prob

        # Build Q-network
        self.q_network = self.build_q_network()

        # Target Q-network (for stability)
        self.target_q_network = self.build_q_network()
        self.target_q_network.set_weights(self.q_network.get_weights())

        # Optimizer
        self.optimizer = tf.keras.optimizers.Adam(learning_rate)

        # Experience replay buffer
        self.memory = []

    def build_q_network(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Dense(64, activation='relu', input_shape=(self.state_space_size,), dtype=tf.float32),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(self.action_space_size)
        ])
        model.compile(optimizer='adam', loss='mse')
        return model

    def select_action(self, state):
      if np.random.rand() < self.exploration_prob:
          return np.random.choice(self.action_space_size)
      else:
          # Convert state index to one-hot encoding
          state_one_hot = np.zeros(self.state_space_size)
          state_one_hot[state] = 1

          # Reshape state for model prediction
          state_one_hot = state_one_hot.reshape(1, -1)  # Reshape to (1, state_space_size)

          # Predict Q-values for the current state
          q_values = self.q_network.predict(state_one_hot)

          # Select action with the highest Q-value
          return np.argmax(q_values[0])

    def update_q_network(self, batch_size, states=None):
      if len(self.memory) < batch_size:
          return

      if states is None:
          # Sample a batch from memory
          samples = np.random.choice(len(self.memory), batch_size, replace=False)
          batch = [self.memory[i] for i in samples]

          # Extract components from the batch
          states, actions, rewards, next_states, dones = zip(*batch)

          # Convert state indices to one-hot encoding
          states = np.eye(len(env.states), dtype=int)[np.array(states)]

          q_values = self.q_network.predict(states)
          next_q_values = self.target_q_network.predict(states)

          # Update Q-values based on Bellman equation
          for i in range(batch_size):
              target = rewards[i] + self.discount_factor * np.max(next_q_values[i]) * (1 - dones[i])
              q_values[i, actions[i]] = target

          # Train the Q-network
          self.q_network.fit(states, q_values, verbose=0)

    def update_target_network(self):
        self.target_q_network.set_weights(self.q_network.get_weights())

# %%
# dopamine values for training
dvalues_range1 = np.random.uniform(0, 39.5, 5000)
dvalues_range2 = np.random.uniform(39.5, 195.8, 5000)
dvalues_range3 = np.random.uniform(39.5, 195.8, 5000)
dopamine_values = np.concatenate((dvalues_range1, dvalues_range2, dvalues_range3))
#np.random.shuffle(dopamine_values)

# acetylcholine values
avalues_range1 = np.random.uniform(2.5,5 , 5000)
avalues_range2 = np.random.uniform(0.5, 2.5, 5000)
avalues_range3 = np.random.uniform(0.5, 2.5, 5000)
acetyl_values = np.concatenate((avalues_range1, avalues_range2, avalues_range3))
#np.random.shuffle(acetyl_values)

# levodopa values
lvalues_range1 = np.random.uniform(0,100 , 5000)
lvalues_range2 = np.random.uniform(100,250, 5000)
lvalues_range3 = np.random.uniform(100,250, 5000)
levodopa_values = np.concatenate((lvalues_range1, lvalues_range2, lvalues_range3))
#np.random.shuffle(acetyl_values)

# %%
# Instantiate the environment and the DQN agent
env = BasalGangliaMDP()
agent = DQNAgent(state_space_size=len(env.states), action_space_size=env.action_space.n)

# Training the DQN agent
num_episodes = 15000
batch_size = 32

for episode in range(num_episodes):

    state_episode = []
    total_reward = 0

    dopamine_value = dopamine_values[episode]
    acetyl_value= acetyl_values[episode]
    levodopa_value=levodopa_values[episode]


    state = env.reset()
    state_episode.append(state)

    print(f"\nEpisode {episode + 1}:")

    while True:
        # Convert state to its corresponding index
        state_index = env.states.index(state)

        action = agent.select_action(state_index)

        # making sure only existing actions is taken.
        while((env.actions[action] not in env.transition_probs[state])):
          action = agent.select_action(state_index)

        next_state, reward, done, _ = env.step(env.actions[action], dopamine_value,acetyl_value,levodopa_value)

        print(f"Transition: {env.states[state_index]} -> {next_state}, Reward: {reward}")

        # Convert next_state to its corresponding index
        next_state_index = env.states.index(next_state)

        # Store experience in replay buffer
        agent.memory.append((state_index, action, reward, next_state_index, done))

        # Update Q-network
        if len(state_episode) >= 2:
            agent.update_q_network(batch_size, states=state_episode)

        if reward is not None:
          total_reward += reward
        state = next_state

        if done:
            break

        # Add more states to the state_episode list
        if len(state_episode) < 10:
            state_episode.append(state)
        else:
            # Remove the first state in the state_episode list
            state_episode.pop(0)
            # Add the current state to the state_episode list
            state_episode.append(state)

    # Update target network periodically
    if episode % 10 == 0:
        agent.update_target_network()

    print(f"Episode: {episode + 1}, Total Reward: {total_reward}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode: 14354, Total Reward: 350.0
#
# Episode 14355:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14355, Total Reward: 0.0
#
# Episode 14356:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14356, Total Reward: 0.0
#
# Episode 14357:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14357, Total Reward: 1400.0
#
# Episode 14358:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14358, Total Reward: 1750.0
#
# Episode 14359:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14359, Total Reward: 350.0
#
# Episode 14360:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14360, Total Reward: 1750.0
#
# Episode 14361:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14361, Total Reward: 1750.0
#
# Episode 14362:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14362, Total Reward: 1400.0
#
# Episode 14363:
# 1/1 [==============================] - 0s 23ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14363, Total Reward: 350.0
#
# Episode 14364:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14364, Total Reward: 0.0
#
# Episode 14365:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14365, Total Reward: 1400.0
#
# Episode 14366:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14366, Total Reward: 350.0
#
# Episode 14367:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14367, Total Reward: 1750.0
#
# Episode 14368:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14368, Total Reward: 1400.0
#
# Episode 14369:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14369, Total Reward: 1400.0
#
# Episode 14370:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14370, Total Reward: 350.0
#
# Episode 14371:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14371, Total Reward: 1750.0
#
# Episode 14372:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14372, Total Reward: 350.0
#
# Episode 14373:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14373, Total Reward: 350.0
#
# Episode 14374:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14374, Total Reward: 1400.0
#
# Episode 14375:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14375, Total Reward: 350.0
#
# Episode 14376:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14376, Total Reward: 1400.0
#
# Episode 14377:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14377, Total Reward: 1750.0
#
# Episode 14378:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14378, Total Reward: 0.0
#
# Episode 14379:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14379, Total Reward: 1400.0
#
# Episode 14380:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14380, Total Reward: 350.0
#
# Episode 14381:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14381, Total Reward: 0.0
#
# Episode 14382:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 36ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14382, Total Reward: 1750.0
#
# Episode 14383:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14383, Total Reward: 1400.0
#
# Episode 14384:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14384, Total Reward: 1750.0
#
# Episode 14385:
# 1/1 [==============================] - 0s 26ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14385, Total Reward: 350.0
#
# Episode 14386:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14386, Total Reward: 1400.0
#
# Episode 14387:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14387, Total Reward: 1750.0
#
# Episode 14388:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14388, Total Reward: 1400.0
#
# Episode 14389:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14389, Total Reward: 350.0
#
# Episode 14390:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14390, Total Reward: 0.0
#
# Episode 14391:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14391, Total Reward: 0.0
#
# Episode 14392:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14392, Total Reward: 350.0
#
# Episode 14393:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14393, Total Reward: 1400.0
#
# Episode 14394:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14394, Total Reward: 350.0
#
# Episode 14395:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14395, Total Reward: 1750.0
#
# Episode 14396:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14396, Total Reward: 0.0
#
# Episode 14397:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14397, Total Reward: 350.0
#
# Episode 14398:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14398, Total Reward: 1750.0
#
# Episode 14399:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14399, Total Reward: 0.0
#
# Episode 14400:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14400, Total Reward: 1750.0
#
# Episode 14401:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14401, Total Reward: 1750.0
#
# Episode 14402:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14402, Total Reward: 0.0
#
# Episode 14403:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14403, Total Reward: 0.0
#
# Episode 14404:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14404, Total Reward: 1750.0
#
# Episode 14405:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14405, Total Reward: 350.0
#
# Episode 14406:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14406, Total Reward: 0.0
#
# Episode 14407:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14407, Total Reward: 350.0
#
# Episode 14408:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14408, Total Reward: 350.0
#
# Episode 14409:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14409, Total Reward: 1400.0
#
# Episode 14410:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14410, Total Reward: 1400.0
#
# Episode 14411:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14411, Total Reward: 1750.0
#
# Episode 14412:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14412, Total Reward: 350.0
#
# Episode 14413:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14413, Total Reward: 1400.0
#
# Episode 14414:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14414, Total Reward: 0.0
#
# Episode 14415:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14415, Total Reward: 0.0
#
# Episode 14416:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14416, Total Reward: 1400.0
#
# Episode 14417:
# 1/1 [==============================] - 0s 25ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14417, Total Reward: 350.0
#
# Episode 14418:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14418, Total Reward: 350.0
#
# Episode 14419:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14419, Total Reward: 0.0
#
# Episode 14420:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14420, Total Reward: 350.0
#
# Episode 14421:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14421, Total Reward: 1750.0
#
# Episode 14422:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14422, Total Reward: 350.0
#
# Episode 14423:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14423, Total Reward: 0.0
#
# Episode 14424:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14424, Total Reward: 0.0
#
# Episode 14425:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14425, Total Reward: 0.0
#
# Episode 14426:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14426, Total Reward: 350.0
#
# Episode 14427:
# 1/1 [==============================] - 0s 26ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14427, Total Reward: 350.0
#
# Episode 14428:
# 1/1 [==============================] - 0s 23ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14428, Total Reward: 1750.0
#
# Episode 14429:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14429, Total Reward: 350.0
#
# Episode 14430:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14430, Total Reward: 0.0
#
# Episode 14431:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14431, Total Reward: 0.0
#
# Episode 14432:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14432, Total Reward: 350.0
#
# Episode 14433:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14433, Total Reward: 1400.0
#
# Episode 14434:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14434, Total Reward: 0.0
#
# Episode 14435:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14435, Total Reward: 1750.0
#
# Episode 14436:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14436, Total Reward: 1400.0
#
# Episode 14437:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14437, Total Reward: 1400.0
#
# Episode 14438:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14438, Total Reward: 0.0
#
# Episode 14439:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14439, Total Reward: 0.0
#
# Episode 14440:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14440, Total Reward: 0.0
#
# Episode 14441:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14441, Total Reward: 1400.0
#
# Episode 14442:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14442, Total Reward: 350.0
#
# Episode 14443:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14443, Total Reward: 350.0
#
# Episode 14444:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14444, Total Reward: 1400.0
#
# Episode 14445:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14445, Total Reward: 0.0
#
# Episode 14446:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14446, Total Reward: 1750.0
#
# Episode 14447:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14447, Total Reward: 1400.0
#
# Episode 14448:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14448, Total Reward: 1750.0
#
# Episode 14449:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14449, Total Reward: 1400.0
#
# Episode 14450:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14450, Total Reward: 1750.0
#
# Episode 14451:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14451, Total Reward: 1750.0
#
# Episode 14452:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14452, Total Reward: 1400.0
#
# Episode 14453:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14453, Total Reward: 350.0
#
# Episode 14454:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14454, Total Reward: 1400.0
#
# Episode 14455:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14455, Total Reward: 350.0
#
# Episode 14456:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14456, Total Reward: 1400.0
#
# Episode 14457:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14457, Total Reward: 1400.0
#
# Episode 14458:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14458, Total Reward: 350.0
#
# Episode 14459:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14459, Total Reward: 0.0
#
# Episode 14460:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14460, Total Reward: 350.0
#
# Episode 14461:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14461, Total Reward: 1400.0
#
# Episode 14462:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14462, Total Reward: 350.0
#
# Episode 14463:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14463, Total Reward: 1750.0
#
# Episode 14464:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14464, Total Reward: 1750.0
#
# Episode 14465:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14465, Total Reward: 1750.0
#
# Episode 14466:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14466, Total Reward: 1400.0
#
# Episode 14467:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14467, Total Reward: 0.0
#
# Episode 14468:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14468, Total Reward: 1400.0
#
# Episode 14469:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14469, Total Reward: 1400.0
#
# Episode 14470:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14470, Total Reward: 1750.0
#
# Episode 14471:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14471, Total Reward: 1400.0
#
# Episode 14472:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14472, Total Reward: 1400.0
#
# Episode 14473:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14473, Total Reward: 350.0
#
# Episode 14474:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14474, Total Reward: 350.0
#
# Episode 14475:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14475, Total Reward: 1750.0
#
# Episode 14476:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14476, Total Reward: 1750.0
#
# Episode 14477:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14477, Total Reward: 1750.0
#
# Episode 14478:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14478, Total Reward: 350.0
#
# Episode 14479:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14479, Total Reward: 1750.0
#
# Episode 14480:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14480, Total Reward: 0.0
#
# Episode 14481:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14481, Total Reward: 0.0
#
# Episode 14482:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14482, Total Reward: 0.0
#
# Episode 14483:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14483, Total Reward: 0.0
#
# Episode 14484:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14484, Total Reward: 1400.0
#
# Episode 14485:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14485, Total Reward: 350.0
#
# Episode 14486:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14486, Total Reward: 1750.0
#
# Episode 14487:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14487, Total Reward: 350.0
#
# Episode 14488:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14488, Total Reward: 1750.0
#
# Episode 14489:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14489, Total Reward: 350.0
#
# Episode 14490:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14490, Total Reward: 1400.0
#
# Episode 14491:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14491, Total Reward: 350.0
#
# Episode 14492:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14492, Total Reward: 0.0
#
# Episode 14493:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14493, Total Reward: 0.0
#
# Episode 14494:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14494, Total Reward: 1750.0
#
# Episode 14495:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14495, Total Reward: 350.0
#
# Episode 14496:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14496, Total Reward: 350.0
#
# Episode 14497:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14497, Total Reward: 1750.0
#
# Episode 14498:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14498, Total Reward: 0.0
#
# Episode 14499:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 40ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14499, Total Reward: 350.0
#
# Episode 14500:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14500, Total Reward: 0.0
#
# Episode 14501:
# 1/1 [==============================] - 0s 36ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14501, Total Reward: 350.0
#
# Episode 14502:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14502, Total Reward: 1750.0
#
# Episode 14503:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14503, Total Reward: 350.0
#
# Episode 14504:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14504, Total Reward: 1750.0
#
# Episode 14505:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14505, Total Reward: 1400.0
#
# Episode 14506:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14506, Total Reward: 350.0
#
# Episode 14507:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 44ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14507, Total Reward: 0.0
#
# Episode 14508:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 40ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14508, Total Reward: 0.0
#
# Episode 14509:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14509, Total Reward: 0.0
#
# Episode 14510:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14510, Total Reward: 1750.0
#
# Episode 14511:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14511, Total Reward: 0.0
#
# Episode 14512:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14512, Total Reward: 1400.0
#
# Episode 14513:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14513, Total Reward: 350.0
#
# Episode 14514:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14514, Total Reward: 0.0
#
# Episode 14515:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14515, Total Reward: 0.0
#
# Episode 14516:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14516, Total Reward: 1400.0
#
# Episode 14517:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14517, Total Reward: 350.0
#
# Episode 14518:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14518, Total Reward: 1400.0
#
# Episode 14519:
# 1/1 [==============================] - 0s 40ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14519, Total Reward: 350.0
#
# Episode 14520:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14520, Total Reward: 1750.0
#
# Episode 14521:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14521, Total Reward: 350.0
#
# Episode 14522:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14522, Total Reward: 0.0
#
# Episode 14523:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14523, Total Reward: 350.0
#
# Episode 14524:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 40ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14524, Total Reward: 1400.0
#
# Episode 14525:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14525, Total Reward: 1750.0
#
# Episode 14526:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14526, Total Reward: 0.0
#
# Episode 14527:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14527, Total Reward: 0.0
#
# Episode 14528:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14528, Total Reward: 1400.0
#
# Episode 14529:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14529, Total Reward: 0.0
#
# Episode 14530:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 40ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14530, Total Reward: 350.0
#
# Episode 14531:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14531, Total Reward: 1400.0
#
# Episode 14532:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14532, Total Reward: 0.0
#
# Episode 14533:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14533, Total Reward: 350.0
#
# Episode 14534:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14534, Total Reward: 1750.0
#
# Episode 14535:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14535, Total Reward: 1400.0
#
# Episode 14536:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14536, Total Reward: 1400.0
#
# Episode 14537:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14537, Total Reward: 0.0
#
# Episode 14538:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14538, Total Reward: 1750.0
#
# Episode 14539:
# Transition: Cortex -> Striatum, Reward: -150.0
# ...
#
# Episode 14938:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14938, Total Reward: 350.0
#
# Episode 14939:
# 1/1 [==============================] - 0s 20ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14939, Total Reward: 350.0
#
# Episode 14940:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14940, Total Reward: 0.0
#
# Episode 14941:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14941, Total Reward: 1400.0
#
# Episode 14942:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14942, Total Reward: 1400.0
#
# Episode 14943:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14943, Total Reward: 1400.0
#
# Episode 14944:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14944, Total Reward: 0.0
#
# Episode 14945:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14945, Total Reward: 0.0
#
# Episode 14946:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14946, Total Reward: 350.0
#
# Episode 14947:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14947, Total Reward: 1400.0
#
# Episode 14948:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14948, Total Reward: 1400.0
#
# Episode 14949:
# 1/1 [==============================] - 0s 21ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14949, Total Reward: 350.0
#
# Episode 14950:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14950, Total Reward: 0.0
#
# Episode 14951:
# 1/1 [==============================] - 0s 20ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14951, Total Reward: 1750.0
#
# Episode 14952:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14952, Total Reward: 0.0
#
# Episode 14953:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14953, Total Reward: 1400.0
#
# Episode 14954:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14954, Total Reward: 0.0
#
# Episode 14955:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14955, Total Reward: 1400.0
#
# Episode 14956:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14956, Total Reward: 1750.0
#
# Episode 14957:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14957, Total Reward: 1400.0
#
# Episode 14958:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14958, Total Reward: 0.0
#
# Episode 14959:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14959, Total Reward: 1400.0
#
# Episode 14960:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14960, Total Reward: 1400.0
#
# Episode 14961:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14961, Total Reward: 350.0
#
# Episode 14962:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14962, Total Reward: 350.0
#
# Episode 14963:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14963, Total Reward: 350.0
#
# Episode 14964:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14964, Total Reward: 1400.0
#
# Episode 14965:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14965, Total Reward: 1400.0
#
# Episode 14966:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14966, Total Reward: 1400.0
#
# Episode 14967:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14967, Total Reward: 1750.0
#
# Episode 14968:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14968, Total Reward: 350.0
#
# Episode 14969:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 19ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14969, Total Reward: 1750.0
#
# Episode 14970:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14970, Total Reward: 1750.0
#
# Episode 14971:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 19ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14971, Total Reward: 350.0
#
# Episode 14972:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14972, Total Reward: 1750.0
#
# Episode 14973:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14973, Total Reward: 1750.0
#
# Episode 14974:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14974, Total Reward: 350.0
#
# Episode 14975:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14975, Total Reward: 0.0
#
# Episode 14976:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14976, Total Reward: 1400.0
#
# Episode 14977:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14977, Total Reward: 1750.0
#
# Episode 14978:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14978, Total Reward: 0.0
#
# Episode 14979:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14979, Total Reward: 350.0
#
# Episode 14980:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14980, Total Reward: 1750.0
#
# Episode 14981:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14981, Total Reward: 0.0
#
# Episode 14982:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14982, Total Reward: 1400.0
#
# Episode 14983:
# 1/1 [==============================] - 0s 27ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14983, Total Reward: 1750.0
#
# Episode 14984:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14984, Total Reward: 1400.0
#
# Episode 14985:
# 1/1 [==============================] - 0s 21ms/step
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14985, Total Reward: 1750.0
#
# Episode 14986:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14986, Total Reward: 1400.0
#
# Episode 14987:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14987, Total Reward: 1400.0
#
# Episode 14988:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14988, Total Reward: 0.0
#
# Episode 14989:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 21ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14989, Total Reward: 1750.0
#
# Episode 14990:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14990, Total Reward: 0.0
#
# Episode 14991:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14991, Total Reward: 350.0
#
# Episode 14992:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14992, Total Reward: 350.0
#
# Episode 14993:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14993, Total Reward: 0.0
#
# Episode 14994:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14994, Total Reward: 350.0
#
# Episode 14995:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 20ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14995, Total Reward: 350.0
#
# Episode 14996:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14996, Total Reward: 0.0
#
# Episode 14997:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14997, Total Reward: 1400.0
#
# Episode 14998:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14998, Total Reward: 1400.0
#
# Episode 14999:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14999, Total Reward: 350.0
#
# Episode 15000:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 15000, Total Reward: 1400.0

# %%
# !pip install dill

import dill

# saving the whole model object.
with open("/content/drive/MyDrive/BASAL/dqn_agent.pkl", "wb") as f:
  dill.dump(agent, f)

with open("/content/drive/MyDrive/BASAL/env.pkl", "wb") as f:
  dill.dump(env, f)
# Out:
# Collecting dill
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.8

# %%
# Loading the model
with open("/content/drive/MyDrive/BASAL/dqn_agent.pkl", "rb") as f:
    loaded_agent = dill.load(f)

with open("/content/drive/MyDrive/BASAL/env.pkl", "rb") as f:
    loaded_env = dill.load(f)
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 13 variables whereas the saved optimizer has 1 variables.
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 13 variables whereas the saved optimizer has 1 variables.

# %%
# Testing the model
no_iterations = 1000
direct_array = ["Cortex", "Striatum", "GPi", "Thalamus"]
indirect_array = ["Cortex", "Striatum", "GPe", "STN", "GPi", "Thalamus"]
accuracy_array = []

for i in range(no_iterations):

    # Testing the trained DQN agent
    state = loaded_env.reset()
    done = False

    output_array = [state]

    dopamine_value = np.random.uniform(0, 195.8, 1)[0]
    acetyl_value = np.random.uniform(0.5, 5, 1)[0]
    levodopa_value = np.random.uniform(0, 250, 1)[0]

    print("\ndopamine : ", dopamine_value, ", acetyl:",acetyl_value, ", levo: ", levodopa_value)

    # Reset exploration probability to 0.1 during testing phase
    loaded_agent.exploration_prob = 0.1

    print(i, " Finally chosen pathway: ")

    while not done:

        # Convert state to its corresponding index
        state_index = loaded_env.states.index(state)

        action = loaded_agent.select_action(state_index)

        # making sure only existing actions is taken.
        while ((loaded_env.actions[action] not in loaded_env.transition_probs[state])):
            action = loaded_agent.select_action(state_index)

        next_state, reward, done, _ = loaded_env.step(
            loaded_env.actions[action], dopamine_value, acetyl_value, levodopa_value)

        print(
            f"Transition: {loaded_env.states[state_index]} -> {next_state}, Reward: {reward}")

        output_array.append(next_state)

        state = next_state

    if (dopamine_value < 39.5):

        if (output_array == indirect_array):
            accuracy_array.append(True)
        else:
            accuracy_array.append(False)

    elif (dopamine_value > 39.6 and dopamine_value < 195.8):

        if (output_array == direct_array):
            accuracy_array.append(True)
        else:
            accuracy_array.append(False)

print("-------------------------------------------------------------")
print("Accuracy: ", (accuracy_array.count(True)/len(accuracy_array)))

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the pathways
direct_pathway_edges = [("Cortex", "Striatum"), ("Striatum", "GPi"), ("GPi", "Thalamus")]
indirect_pathway_edges = [("Cortex", "Striatum"), ("Striatum", "GPe"), ("GPe", "STN"), ("STN", "GPi"), ("GPi", "Thalamus")]
on=""

# Create a graph
G = nx.DiGraph()

# Add edges for direct pathway
G.add_edges_from(direct_pathway_edges)

# Add edges for indirect pathway
G.add_edges_from(indirect_pathway_edges)

# Testing the trained DQN agent
state = loaded_env.reset()
done = False

output_array = [state]

dopamine_value = np.random.uniform(0,196)
acetyl_value = np.random.uniform(0,5)
levodopa_value = np.random.uniform(0,250)
print("\ndopamine : ", dopamine_value)

while not done:
    # Convert state to its corresponding index
    state_index = loaded_env.states.index(state)

    action = loaded_agent.select_action(state_index)

    # making sure only existing actions are taken.
    while ((loaded_env.actions[action] not in loaded_env.transition_probs[state])):
            action = loaded_agent.select_action(state_index)

    next_state, reward, done, _ = loaded_env.step(
            loaded_env.actions[action], dopamine_value, acetyl_value, levodopa_value)
    #print(f"Transition: {env.states[state_index]} -> {next_state}, Reward: {reward}")

    output_array.append(next_state)

    state = next_state

# Create a directed graph
output_graph = nx.DiGraph()

# Add nodes and edges based on the output array
for i in range(len(output_array) - 1):
    output_graph.add_edge(output_array[i], output_array[i+1])

# Check conditions and visualize the graph accordingly
if dopamine_value < 39.5:
    if output_array == indirect_array:
        on="1"
        plt.title("Indirect Pathway")
        nx.draw(output_graph, with_labels=True, node_size=2500, node_color="white", edgecolors="black", linewidths=1.5, font_size=10, font_weight="bold", arrowsize=20)
    else:
        print("Pathway not found.")

elif dopamine_value > 39.6 and dopamine_value < 195.8:
    if output_array == direct_array:
        om="0"
        plt.title("Direct Pathway")
        nx.draw(output_graph,with_labels=True, node_size=2500, node_color="white", edgecolors="black", linewidths=1.5, font_size=10, font_weight="bold", arrowsize=20)
    else:
        print("Pathway not found.")

plt.show()

# %%
import pandas as pd

# Read the text file into a DataFrame
df_pd = pd.read_csv('/content/drive/MyDrive/BASAL/dummyGeneActiveData_Day1.txt', delimiter='\t')
df_nonpd = pd.read_csv("/content/drive/MyDrive/BASAL/dummyPebbleData_Day1.txt", delimiter="\t")

# Calculate the average for each column
average_values_pd = df_pd.mean()
average_values_nonpd = df_nonpd.mean()

# Display the average values
print("Average values:")
print(average_values_nonpd)

# %%
# final ouput from the model
if(output_array == indirect_array):
  file_content= "2,"+average_values_pd[1]+","+average_values_pd[2]+","+average_values_pd[3]
elif(output_array == direct_array):
  file_content= "1,"+average_values_nonpd[1]+","+average_values_nonpd[2]+","+average_values_nonpd[3]

# %%
from google.colab import files

def upload_file():
    uploaded = files.upload()
    for filename in uploaded.keys():
        print('File uploaded:', filename)
        return filename  # Return the name of the uploaded file

uploaded_filename = upload_file()

if uploaded_filename:
    with open(uploaded_filename, 'r') as file:
        content = file.read()

    # Check if the content matches the expected text
    if content.strip() == "Robo arm ready!":
       with open('roboarm.txt', 'w') as file:
          file.write(file_content)
       files.download('roboarm.txt')
