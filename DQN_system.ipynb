# %% [markdown]
# <a href="https://colab.research.google.com/github/nivedita-rajesh/BasalGanglia/blob/main/Final_DQN_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gym
import numpy as np
import tensorflow as tf
from google.colab import drive
import os
import joblib
from datetime import datetime

drive.mount('/content/drive')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = "1"
# Out:
# Mounted at /content/drive

# %%
class BasalGangliaMDP(gym.Env):
    def __init__(self):
        super().__init__()

        # Define states
        self.states = ['Cortex', 'Striatum', 'GPe', 'STN', 'GPi', 'Thalamus']

        # Define actions
        self.actions = ["activation", "inhibition"]
        self.action_space = gym.spaces.Discrete(len(self.actions))

        self.transition_probs = {
            "Cortex": {
                "activation": { "Striatum": 1.0 },
                "inhibition": { "Striatum": 1.0 }
            },
            "Striatum": {
                "inhibition": { 'GPe': 0.5, 'GPi': 0.5 },
            },
            "GPe": {
                "inhibition": { "STN": 1.0 },
            },
            "STN": {
                "activation": { "GPi": 1.0 },
            },
            "GPi": {
                "inhibition": { "Thalamus": 1.0 },
            },
            "Thalamus": {
                "activation": { "Cortex": 1.0 },
            }
        }

        self.rewards = {
            ("Cortex", "activation", "Striatum") : 1.0,
            ("Cortex", "inhibition", "Striatum") : 1.0,

            ("Striatum", "inhibition", "GPe") : 1.0,
            ("Striatum", "inhibition", "GPi") : 1.0,

            ("GPe", "inhibition", "STN") : 1.0,

            ("STN", "activation", "GPi") : 1.0,

            ("GPi", "inhibition", "Thalamus") : 1.0,

            ("Thalamus", "activation", "Cortex") : 1.0
        }

        self.state = 'Cortex'  # Initial state

    def calculate_rewards(self, state, action, next_state, dopamine, acetyl, levodopa):
          if(dopamine <= 39.6 and acetyl > 2.5 and levodopa < 100):
            if(state == "Cortex" and next_state == "Striatum"):
              if(action == "activation"):
                return self.rewards.get((self.state, action, next_state), 0) * -100
              elif(action == "inhibition"):
                return self.rewards.get((self.state, action, next_state), 0) * 250

            elif(state=="Striatum" and next_state=="GPe"):
                return self.rewards.get((self.state, action, next_state), 0) * 400

            elif(state=="Striatum" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * -250

            elif(state=="GPe" and next_state=="STN"):
                return self.rewards.get((self.state, action, next_state), 0) * 500

            elif(state=="STN" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * 600

            elif(state=="GPi" and next_state=="Thalamus"):
                return self.rewards.get((self.state, action, next_state), 0) * 800

            else:
                raise Exception("Get good bro")


          elif(dopamine <= 39.6 and acetyl > 2.5 and levodopa >= 100 and levodopa <=250):
            if(state == "Cortex" and next_state == "Striatum"):
              if(action == "activation"):
                return self.rewards.get((self.state, action, next_state), 0) * 200

              elif(action == "inhibition"):
                return self.rewards.get((self.state, action, next_state), 0) * -150

            elif(state=="Striatum" and next_state=="GPe"):
                return self.rewards.get((self.state, action, next_state), 0) * -200

            elif(state=="Striatum" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * 450

            elif(state=="GPe" and next_state=="STN"):
                return self.rewards.get((self.state, action, next_state), 0) * -300

            elif(state=="STN" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * -350

            elif(state=="GPi" and next_state=="Thalamus"):
                return self.rewards.get((self.state, action, next_state), 0) * 1000

            else:
                raise Exception("Get good bro")


          elif(dopamine > 39.6 and dopamine <= 195.8 and acetyl >=0.5 and acetyl <= 2.5):
            if(state == "Cortex" and next_state == "Striatum"):
              if(action == "activation"):
                return self.rewards.get((self.state, action, next_state), 0) * 200

              elif(action == "inhibition"):
                return self.rewards.get((self.state, action, next_state), 0) * -150

            elif(state=="Striatum" and next_state=="GPe"):
                return self.rewards.get((self.state, action, next_state), 0) * -200

            elif(state=="Striatum" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * 550

            elif(state=="GPe" and next_state=="STN"):
                return self.rewards.get((self.state, action, next_state), 0) * -300

            elif(state=="STN" and next_state=="GPi"):
                return self.rewards.get((self.state, action, next_state), 0) * -350

            elif(state=="GPi" and next_state=="Thalamus"):
                return self.rewards.get((self.state, action, next_state), 0) * 1000

            else:
                raise Exception("Get good bro")


    def step(self, action, dopamine, acetyl, levodopa):

        next_state_probs = self.transition_probs[self.state][action]
        next_state = np.random.choice(list(next_state_probs.keys()), p=list(next_state_probs.values()))

        # reward = self.rewards.get((self.state, action, next_state), 0)

        reward = self.calculate_rewards(self.state, action, next_state, dopamine, acetyl, levodopa)

        self.state = next_state

        done = next_state == 'Thalamus'  # Terminal state
        info = {}

        return next_state, reward, done, info

    def reset(self):
        self.state = 'Cortex'
        return self.state

    def render(self):
        print(self.state)

# %%
class DQNAgent:
    def __init__(self, state_space_size, action_space_size, learning_rate=0.001, discount_factor=0.9, exploration_prob=0.9):
        self.state_space_size = state_space_size
        self.action_space_size = action_space_size
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.exploration_prob = exploration_prob

        # Build Q-network
        self.q_network = self.build_q_network()

        # Target Q-network (for stability)
        self.target_q_network = self.build_q_network()
        self.target_q_network.set_weights(self.q_network.get_weights())

        # Optimizer
        self.optimizer = tf.keras.optimizers.Adam(learning_rate)

        # Experience replay buffer
        self.memory = []

    def build_q_network(self):
        model = tf.keras.Sequential([
            tf.keras.layers.Dense(64, activation='relu', input_shape=(self.state_space_size,), dtype=tf.float32),
            tf.keras.layers.Dense(64, activation='relu'),
            tf.keras.layers.Dense(self.action_space_size)
        ])
        model.compile(optimizer='adam', loss='mse')
        return model

    def select_action(self, state):
      if np.random.rand() < self.exploration_prob:
          return np.random.choice(self.action_space_size)
      else:
          # Convert state index to one-hot encoding
          state_one_hot = np.zeros(self.state_space_size)
          state_one_hot[state] = 1

          # Reshape state for model prediction
          state_one_hot = state_one_hot.reshape(1, -1)  # Reshape to (1, state_space_size)

          # Predict Q-values for the current state
          q_values = self.q_network.predict(state_one_hot)

          # Select action with the highest Q-value
          return np.argmax(q_values[0])

    def update_q_network(self, batch_size, states=None):
      if len(self.memory) < batch_size:
          return

      if states is None:
          # Sample a batch from memory
          samples = np.random.choice(len(self.memory), batch_size, replace=False)
          batch = [self.memory[i] for i in samples]

          # Extract components from the batch
          states, actions, rewards, next_states, dones = zip(*batch)

          # Convert state indices to one-hot encoding
          states = np.eye(len(env.states), dtype=int)[np.array(states)]

          q_values = self.q_network.predict(states)
          next_q_values = self.target_q_network.predict(states)

          # Update Q-values based on Bellman equation
          for i in range(batch_size):
              target = rewards[i] + self.discount_factor * np.max(next_q_values[i]) * (1 - dones[i])
              q_values[i, actions[i]] = target

          # Train the Q-network
          self.q_network.fit(states, q_values, verbose=0)

    def update_target_network(self):
        self.target_q_network.set_weights(self.q_network.get_weights())

# %%
# dopamine values for training
dvalues_range1 = np.random.uniform(0, 39.5, 5000)
dvalues_range2 = np.random.uniform(39.5, 195.8, 5000)
dvalues_range3 = np.random.uniform(39.5, 195.8, 5000)
dopamine_values = np.concatenate((dvalues_range1, dvalues_range2, dvalues_range3))
#np.random.shuffle(dopamine_values)

# acetylcholine values
avalues_range1 = np.random.uniform(2.5,5 , 5000)
avalues_range2 = np.random.uniform(0.5, 2.5, 5000)
avalues_range3 = np.random.uniform(0.5, 2.5, 5000)
acetyl_values = np.concatenate((avalues_range1, avalues_range2, avalues_range3))
#np.random.shuffle(acetyl_values)

# levodopa values
lvalues_range1 = np.random.uniform(0,100 , 5000)
lvalues_range2 = np.random.uniform(100,250, 5000)
lvalues_range3 = np.random.uniform(100,250, 5000)
levodopa_values = np.concatenate((lvalues_range1, lvalues_range2, lvalues_range3))
#np.random.shuffle(acetyl_values)

# %%
# Instantiate the environment and the DQN agent
env = BasalGangliaMDP()
agent = DQNAgent(state_space_size=len(env.states), action_space_size=env.action_space.n)

# Training the DQN agent
num_episodes = 15000
batch_size = 32

for episode in range(num_episodes):

    state_episode = []
    total_reward = 0

    dopamine_value = dopamine_values[episode]
    acetyl_value= acetyl_values[episode]
    levodopa_value=levodopa_values[episode]


    state = env.reset()
    state_episode.append(state)

    print(f"\nEpisode {episode + 1}:")

    while True:
        # Convert state to its corresponding index
        state_index = env.states.index(state)

        action = agent.select_action(state_index)

        # making sure only existing actions is taken.
        while((env.actions[action] not in env.transition_probs[state])):
          action = agent.select_action(state_index)

        next_state, reward, done, _ = env.step(env.actions[action], dopamine_value,acetyl_value,levodopa_value)

        print(f"Transition: {env.states[state_index]} -> {next_state}, Reward: {reward}")

        # Convert next_state to its corresponding index
        next_state_index = env.states.index(next_state)

        # Store experience in replay buffer
        agent.memory.append((state_index, action, reward, next_state_index, done))

        # Update Q-network
        if len(state_episode) >= 2:
            agent.update_q_network(batch_size, states=state_episode)

        if reward is not None:
          total_reward += reward
        state = next_state

        if done:
            break

        # Add more states to the state_episode list
        if len(state_episode) < 10:
            state_episode.append(state)
        else:
            # Remove the first state in the state_episode list
            state_episode.pop(0)
            # Add the current state to the state_episode list
            state_episode.append(state)

    # Update target network periodically
    if episode % 10 == 0:
        agent.update_target_network()

    print(f"Episode: {episode + 1}, Total Reward: {total_reward}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode 14351:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14351, Total Reward: 0.0
#
# Episode 14352:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14352, Total Reward: 350.0
#
# Episode 14353:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14353, Total Reward: 1400.0
#
# Episode 14354:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 62ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 51ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14354, Total Reward: 350.0
#
# Episode 14355:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 36ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 49ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14355, Total Reward: 0.0
#
# Episode 14356:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14356, Total Reward: 1400.0
#
# Episode 14357:
# 1/1 [==============================] - 0s 49ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 49ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14357, Total Reward: 0.0
#
# Episode 14358:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14358, Total Reward: 1400.0
#
# Episode 14359:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 36ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14359, Total Reward: 0.0
#
# Episode 14360:
# 1/1 [==============================] - 0s 38ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 40ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14360, Total Reward: 0.0
#
# Episode 14361:
# 1/1 [==============================] - 0s 65ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 43ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14361, Total Reward: 0.0
#
# Episode 14362:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14362, Total Reward: 1750.0
#
# Episode 14363:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 51ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14363, Total Reward: 350.0
#
# Episode 14364:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 55ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14364, Total Reward: 0.0
#
# Episode 14365:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 43ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 47ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14365, Total Reward: 350.0
#
# Episode 14366:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14366, Total Reward: 0.0
#
# Episode 14367:
# 1/1 [==============================] - 0s 35ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14367, Total Reward: 1400.0
#
# Episode 14368:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14368, Total Reward: 1400.0
#
# Episode 14369:
# 1/1 [==============================] - 0s 44ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14369, Total Reward: 0.0
#
# Episode 14370:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14370, Total Reward: 350.0
#
# Episode 14371:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 48ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14371, Total Reward: 1400.0
#
# Episode 14372:
# 1/1 [==============================] - 0s 51ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14372, Total Reward: 0.0
#
# Episode 14373:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 48ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14373, Total Reward: 0.0
#
# Episode 14374:
# 1/1 [==============================] - 0s 38ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14374, Total Reward: 1400.0
#
# Episode 14375:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14375, Total Reward: 350.0
#
# Episode 14376:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14376, Total Reward: 0.0
#
# Episode 14377:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14377, Total Reward: 1750.0
#
# Episode 14378:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14378, Total Reward: 350.0
#
# Episode 14379:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14379, Total Reward: 350.0
#
# Episode 14380:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14380, Total Reward: 0.0
#
# Episode 14381:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14381, Total Reward: 350.0
#
# Episode 14382:
# 1/1 [==============================] - 0s 26ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14382, Total Reward: 0.0
#
# Episode 14383:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14383, Total Reward: 1400.0
#
# Episode 14384:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14384, Total Reward: 1750.0
#
# Episode 14385:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14385, Total Reward: 1750.0
#
# Episode 14386:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14386, Total Reward: 1400.0
#
# Episode 14387:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14387, Total Reward: 1750.0
#
# Episode 14388:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14388, Total Reward: 1750.0
#
# Episode 14389:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14389, Total Reward: 0.0
#
# Episode 14390:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14390, Total Reward: 1750.0
#
# Episode 14391:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14391, Total Reward: 1400.0
#
# Episode 14392:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14392, Total Reward: 1750.0
#
# Episode 14393:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14393, Total Reward: 350.0
#
# Episode 14394:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14394, Total Reward: 1750.0
#
# Episode 14395:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14395, Total Reward: 1750.0
#
# Episode 14396:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14396, Total Reward: 1750.0
#
# Episode 14397:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 38ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14397, Total Reward: 0.0
#
# Episode 14398:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14398, Total Reward: 1750.0
#
# Episode 14399:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14399, Total Reward: 1750.0
#
# Episode 14400:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14400, Total Reward: 0.0
#
# Episode 14401:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14401, Total Reward: 1750.0
#
# Episode 14402:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14402, Total Reward: 1750.0
#
# Episode 14403:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14403, Total Reward: 0.0
#
# Episode 14404:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14404, Total Reward: 0.0
#
# Episode 14405:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14405, Total Reward: 1400.0
#
# Episode 14406:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14406, Total Reward: 1400.0
#
# Episode 14407:
# 1/1 [==============================] - 0s 31ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14407, Total Reward: 1400.0
#
# Episode 14408:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14408, Total Reward: 1400.0
#
# Episode 14409:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14409, Total Reward: 1750.0
#
# Episode 14410:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14410, Total Reward: 0.0
#
# Episode 14411:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14411, Total Reward: 1400.0
#
# Episode 14412:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14412, Total Reward: 350.0
#
# Episode 14413:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14413, Total Reward: 1750.0
#
# Episode 14414:
# 1/1 [==============================] - 0s 25ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 33ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14414, Total Reward: 0.0
#
# Episode 14415:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14415, Total Reward: 0.0
#
# Episode 14416:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14416, Total Reward: 0.0
#
# Episode 14417:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14417, Total Reward: 1400.0
#
# Episode 14418:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14418, Total Reward: 1400.0
#
# Episode 14419:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14419, Total Reward: 1750.0
#
# Episode 14420:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14420, Total Reward: 0.0
#
# Episode 14421:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14421, Total Reward: 1400.0
#
# Episode 14422:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14422, Total Reward: 350.0
#
# Episode 14423:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14423, Total Reward: 0.0
#
# Episode 14424:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14424, Total Reward: 350.0
#
# Episode 14425:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14425, Total Reward: 1750.0
#
# Episode 14426:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14426, Total Reward: 0.0
#
# Episode 14427:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14427, Total Reward: 0.0
#
# Episode 14428:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14428, Total Reward: 1750.0
#
# Episode 14429:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14429, Total Reward: 350.0
#
# Episode 14430:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14430, Total Reward: 350.0
#
# Episode 14431:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14431, Total Reward: 1750.0
#
# Episode 14432:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14432, Total Reward: 1400.0
#
# Episode 14433:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14433, Total Reward: 1400.0
#
# Episode 14434:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14434, Total Reward: 0.0
#
# Episode 14435:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 41ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14435, Total Reward: 350.0
#
# Episode 14436:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14436, Total Reward: 350.0
#
# Episode 14437:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14437, Total Reward: 350.0
#
# Episode 14438:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14438, Total Reward: 1750.0
#
# Episode 14439:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14439, Total Reward: 1750.0
#
# Episode 14440:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14440, Total Reward: 0.0
#
# Episode 14441:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14441, Total Reward: 1400.0
#
# Episode 14442:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14442, Total Reward: 0.0
#
# Episode 14443:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14443, Total Reward: 1400.0
#
# Episode 14444:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14444, Total Reward: 1400.0
#
# Episode 14445:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14445, Total Reward: 1400.0
#
# Episode 14446:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14446, Total Reward: 1400.0
#
# Episode 14447:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14447, Total Reward: 350.0
#
# Episode 14448:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14448, Total Reward: 350.0
#
# Episode 14449:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14449, Total Reward: 350.0
#
# Episode 14450:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14450, Total Reward: 350.0
#
# Episode 14451:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14451, Total Reward: 1400.0
#
# Episode 14452:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14452, Total Reward: 0.0
#
# Episode 14453:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14453, Total Reward: 350.0
#
# Episode 14454:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14454, Total Reward: 1750.0
#
# Episode 14455:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14455, Total Reward: 1400.0
#
# Episode 14456:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14456, Total Reward: 350.0
#
# Episode 14457:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14457, Total Reward: 1400.0
#
# Episode 14458:
# 1/1 [==============================] - 0s 31ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14458, Total Reward: 0.0
#
# Episode 14459:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14459, Total Reward: 0.0
#
# Episode 14460:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14460, Total Reward: 0.0
#
# Episode 14461:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14461, Total Reward: 1750.0
#
# Episode 14462:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14462, Total Reward: 1400.0
#
# Episode 14463:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14463, Total Reward: 0.0
#
# Episode 14464:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14464, Total Reward: 1400.0
#
# Episode 14465:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14465, Total Reward: 0.0
#
# Episode 14466:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14466, Total Reward: 350.0
#
# Episode 14467:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14467, Total Reward: 350.0
#
# Episode 14468:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14468, Total Reward: 1400.0
#
# Episode 14469:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14469, Total Reward: 1400.0
#
# Episode 14470:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14470, Total Reward: 1400.0
#
# Episode 14471:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14471, Total Reward: 0.0
#
# Episode 14472:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14472, Total Reward: 1400.0
#
# Episode 14473:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14473, Total Reward: 1400.0
#
# Episode 14474:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14474, Total Reward: 0.0
#
# Episode 14475:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14475, Total Reward: 1750.0
#
# Episode 14476:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14476, Total Reward: 350.0
#
# Episode 14477:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14477, Total Reward: 1750.0
#
# Episode 14478:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14478, Total Reward: 1400.0
#
# Episode 14479:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14479, Total Reward: 1400.0
#
# Episode 14480:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14480, Total Reward: 1400.0
#
# Episode 14481:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14481, Total Reward: 350.0
#
# Episode 14482:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14482, Total Reward: 1750.0
#
# Episode 14483:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14483, Total Reward: 1750.0
#
# Episode 14484:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14484, Total Reward: 1400.0
#
# Episode 14485:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14485, Total Reward: 1400.0
#
# Episode 14486:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14486, Total Reward: 0.0
#
# Episode 14487:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14487, Total Reward: 350.0
#
# Episode 14488:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14488, Total Reward: 0.0
#
# Episode 14489:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14489, Total Reward: 350.0
#
# Episode 14490:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14490, Total Reward: 0.0
#
# Episode 14491:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14491, Total Reward: 0.0
#
# Episode 14492:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14492, Total Reward: 1750.0
#
# Episode 14493:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14493, Total Reward: 1400.0
#
# Episode 14494:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14494, Total Reward: 1400.0
#
# Episode 14495:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14495, Total Reward: 1400.0
#
# Episode 14496:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14496, Total Reward: 0.0
#
# Episode 14497:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14497, Total Reward: 350.0
#
# Episode 14498:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 44ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14498, Total Reward: 1400.0
#
# Episode 14499:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14499, Total Reward: 1400.0
#
# Episode 14500:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 41ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14500, Total Reward: 0.0
#
# Episode 14501:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14501, Total Reward: 0.0
#
# Episode 14502:
# 1/1 [==============================] - 0s 37ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 42ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14502, Total Reward: 0.0
#
# Episode 14503:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14503, Total Reward: 0.0
#
# Episode 14504:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14504, Total Reward: 1750.0
#
# Episode 14505:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14505, Total Reward: 350.0
#
# Episode 14506:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14506, Total Reward: 1400.0
#
# Episode 14507:
# 1/1 [==============================] - 0s 45ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14507, Total Reward: 1400.0
#
# Episode 14508:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 56ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14508, Total Reward: 350.0
#
# Episode 14509:
# 1/1 [==============================] - 0s 33ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14509, Total Reward: 0.0
#
# Episode 14510:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14510, Total Reward: 350.0
#
# Episode 14511:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 36ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14511, Total Reward: 0.0
#
# Episode 14512:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14512, Total Reward: 1750.0
#
# Episode 14513:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14513, Total Reward: 350.0
#
# Episode 14514:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14514, Total Reward: 1750.0
#
# Episode 14515:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14515, Total Reward: 1400.0
#
# Episode 14516:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 52ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 40ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14516, Total Reward: 0.0
#
# Episode 14517:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14517, Total Reward: 1400.0
#
# Episode 14518:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 47ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14518, Total Reward: 0.0
#
# Episode 14519:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 41ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14519, Total Reward: 350.0
#
# Episode 14520:
# 1/1 [==============================] - 0s 51ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14520, Total Reward: 1400.0
#
# Episode 14521:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14521, Total Reward: 0.0
#
# Episode 14522:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14522, Total Reward: 350.0
#
# Episode 14523:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 33ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14523, Total Reward: 0.0
#
# Episode 14524:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14524, Total Reward: 0.0
#
# Episode 14525:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14525, Total Reward: 350.0
#
# Episode 14526:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14526, Total Reward: 1750.0
#
# Episode 14527:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14527, Total Reward: 1750.0
#
# Episode 14528:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14528, Total Reward: 350.0
#
# Episode 14529:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14529, Total Reward: 1750.0
#
# Episode 14530:
# 1/1 [==============================] - 0s 35ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 38ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 46ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14530, Total Reward: 1400.0
#
# Episode 14531:
# ...
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14938, Total Reward: 1400.0
#
# Episode 14939:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14939, Total Reward: 1400.0
#
# Episode 14940:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14940, Total Reward: 350.0
#
# Episode 14941:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14941, Total Reward: 1750.0
#
# Episode 14942:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14942, Total Reward: 1400.0
#
# Episode 14943:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14943, Total Reward: 1750.0
#
# Episode 14944:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14944, Total Reward: 0.0
#
# Episode 14945:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14945, Total Reward: 1400.0
#
# Episode 14946:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14946, Total Reward: 1400.0
#
# Episode 14947:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 22ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14947, Total Reward: 1750.0
#
# Episode 14948:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14948, Total Reward: 0.0
#
# Episode 14949:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14949, Total Reward: 1750.0
#
# Episode 14950:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14950, Total Reward: 350.0
#
# Episode 14951:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14951, Total Reward: 1400.0
#
# Episode 14952:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14952, Total Reward: 0.0
#
# Episode 14953:
# 1/1 [==============================] - 0s 23ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14953, Total Reward: 1400.0
#
# Episode 14954:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14954, Total Reward: 1750.0
#
# Episode 14955:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14955, Total Reward: 0.0
#
# Episode 14956:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14956, Total Reward: 0.0
#
# Episode 14957:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14957, Total Reward: 0.0
#
# Episode 14958:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14958, Total Reward: 1750.0
#
# Episode 14959:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14959, Total Reward: 1750.0
#
# Episode 14960:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14960, Total Reward: 1400.0
#
# Episode 14961:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14961, Total Reward: 1750.0
#
# Episode 14962:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 33ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14962, Total Reward: 0.0
#
# Episode 14963:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14963, Total Reward: 350.0
#
# Episode 14964:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14964, Total Reward: 0.0
#
# Episode 14965:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14965, Total Reward: 0.0
#
# Episode 14966:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14966, Total Reward: 1400.0
#
# Episode 14967:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14967, Total Reward: 0.0
#
# Episode 14968:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14968, Total Reward: 1750.0
#
# Episode 14969:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 23ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14969, Total Reward: 1750.0
#
# Episode 14970:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14970, Total Reward: 1750.0
#
# Episode 14971:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14971, Total Reward: 0.0
#
# Episode 14972:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14972, Total Reward: 350.0
#
# Episode 14973:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14973, Total Reward: 350.0
#
# Episode 14974:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14974, Total Reward: 0.0
#
# Episode 14975:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14975, Total Reward: 1400.0
#
# Episode 14976:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14976, Total Reward: 350.0
#
# Episode 14977:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14977, Total Reward: 350.0
#
# Episode 14978:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14978, Total Reward: 350.0
#
# Episode 14979:
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14979, Total Reward: 1400.0
#
# Episode 14980:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14980, Total Reward: 0.0
#
# Episode 14981:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14981, Total Reward: 1750.0
#
# Episode 14982:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14982, Total Reward: 1400.0
#
# Episode 14983:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14983, Total Reward: 1750.0
#
# Episode 14984:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14984, Total Reward: 0.0
#
# Episode 14985:
# 1/1 [==============================] - 0s 27ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14985, Total Reward: 0.0
#
# Episode 14986:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14986, Total Reward: 350.0
#
# Episode 14987:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14987, Total Reward: 350.0
#
# Episode 14988:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14988, Total Reward: 1400.0
#
# Episode 14989:
# 1/1 [==============================] - 0s 25ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14989, Total Reward: 1400.0
#
# Episode 14990:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14990, Total Reward: 1750.0
#
# Episode 14991:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14991, Total Reward: 350.0
#
# Episode 14992:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14992, Total Reward: 1400.0
#
# Episode 14993:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14993, Total Reward: 1400.0
#
# Episode 14994:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14994, Total Reward: 1400.0
#
# Episode 14995:
# Transition: Cortex -> Striatum, Reward: 200.0
# 1/1 [==============================] - 0s 24ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14995, Total Reward: 1750.0
#
# Episode 14996:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14996, Total Reward: 1750.0
#
# Episode 14997:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14997, Total Reward: 1750.0
#
# Episode 14998:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14998, Total Reward: 0.0
#
# Episode 14999:
# Transition: Cortex -> Striatum, Reward: 200.0
# Transition: Striatum -> GPi, Reward: 550.0
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 14999, Total Reward: 1750.0
#
# Episode 15000:
# Transition: Cortex -> Striatum, Reward: -150.0
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
# Episode: 15000, Total Reward: 0.0

# %%
# !pip install dill

import dill

# saving the whole model object.
with open("/content/drive/MyDrive/BASAL/dqn_agent.pkl", "wb") as f:
  dill.dump(agent, f)

with open("/content/drive/MyDrive/BASAL/env.pkl", "wb") as f:
  dill.dump(env, f)
# Out:
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (0.3.8)

# %%
# Loading the model
with open("/content/drive/MyDrive/BASAL/dqn_agent.pkl", "rb") as f:
    loaded_agent = dill.load(f)

with open("/content/drive/MyDrive/BASAL/env.pkl", "rb") as f:
    loaded_env = dill.load(f)
# Out:
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 13 variables whereas the saved optimizer has 1 variables.
# WARNING:absl:Skipping variable loading for optimizer 'Adam', because it has 13 variables whereas the saved optimizer has 1 variables.

# %%
# Testing the model
no_iterations = 1000
direct_array = ["Cortex", "Striatum", "GPi", "Thalamus"]
indirect_array = ["Cortex", "Striatum", "GPe", "STN", "GPi", "Thalamus"]
accuracy_array = []

for i in range(no_iterations):

    # Testing the trained DQN agent
    state = loaded_env.reset()
    done = False

    output_array = [state]

    dopamine_value = np.random.uniform(0, 195.8, 1)[0]
    acetyl_value = np.random.uniform(0.5, 5, 1)[0]
    levodopa_value = np.random.uniform(0, 250, 1)[0]

    print("\ndopamine : ", dopamine_value, ", acetyl:",acetyl_value, ", levo: ", levodopa_value)

    # Reset exploration probability to 0.1 during testing phase
    loaded_agent.exploration_prob = 0.1

    print(i, " Finally chosen pathway: ")

    while not done:

        # Convert state to its corresponding index
        state_index = loaded_env.states.index(state)

        action = loaded_agent.select_action(state_index)

        # making sure only existing actions is taken.
        while ((loaded_env.actions[action] not in loaded_env.transition_probs[state])):
            action = loaded_agent.select_action(state_index)

        next_state, reward, done, _ = loaded_env.step(
            loaded_env.actions[action], dopamine_value, acetyl_value, levodopa_value)

        print(
            f"Transition: {loaded_env.states[state_index]} -> {next_state}, Reward: {reward}")

        output_array.append(next_state)

        state = next_state

    if (dopamine_value < 39.5):

        if (output_array == indirect_array):
            accuracy_array.append(True)
        else:
            accuracy_array.append(False)

    elif (dopamine_value > 39.6 and dopamine_value < 195.8):

        if (output_array == direct_array):
            accuracy_array.append(True)
        else:
            accuracy_array.append(False)

print("-------------------------------------------------------------")
print("Accuracy: ", (accuracy_array.count(True)/len(accuracy_array)))
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 67ms/step
# Transition: STN -> GPi, Reward: -350.0
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  59.11248471159978 , acetyl: 3.7353260972572926 , levo:  180.69132210018964
# 760  Finally chosen pathway:
# 1/1 [==============================] - 0s 35ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 45ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 38ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  52.0257092164917 , acetyl: 2.6534982347962375 , levo:  152.4403654138508
# 761  Finally chosen pathway:
# 1/1 [==============================] - 0s 33ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 51ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  78.77773498958061 , acetyl: 3.410548906076346 , levo:  115.21334668712538
# 762  Finally chosen pathway:
# 1/1 [==============================] - 0s 37ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 44ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 46ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  116.27119423082705 , acetyl: 1.7932952602473722 , levo:  149.9249967368249
# 763  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  61.15584650337948 , acetyl: 3.0710283615222504 , levo:  40.6564447800713
# 764  Finally chosen pathway:
# 1/1 [==============================] - 0s 33ms/step
# Transition: Cortex -> Striatum, Reward: None
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  15.107901285371234 , acetyl: 4.7323781671009595 , levo:  89.57853295028382
# 765  Finally chosen pathway:
# 1/1 [==============================] - 0s 31ms/step
# Transition: Cortex -> Striatum, Reward: 250.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: Striatum -> GPi, Reward: -250.0
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPi -> Thalamus, Reward: 800.0
#
# dopamine :  41.12789704826831 , acetyl: 3.374211681725121 , levo:  1.2081857715582622
# 766  Finally chosen pathway:
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 66ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 59ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  37.518944309821634 , acetyl: 2.396545492112799 , levo:  19.97775211727881
# 767  Finally chosen pathway:
# 1/1 [==============================] - 0s 59ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 39ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 49ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  35.87741725418417 , acetyl: 2.4293760989668733 , levo:  187.05532012973092
# 768  Finally chosen pathway:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  24.64991159484822 , acetyl: 0.5611750275224594 , levo:  17.62188110461932
# 769  Finally chosen pathway:
# 1/1 [==============================] - 0s 37ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  184.1623734781318 , acetyl: 1.6998401554624571 , levo:  3.6799798042176644
# 770  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 41ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  183.59890392153193 , acetyl: 2.1867592585388986 , levo:  113.54674460644368
# 771  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  72.39545875980983 , acetyl: 2.0811734818159158 , levo:  67.18876700473547
# 772  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 33ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  67.30449574576897 , acetyl: 0.8886127154650377 , levo:  229.3726880760364
# 773  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 39ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 58ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  110.37696207656548 , acetyl: 0.5892402512011754 , levo:  34.58380202583539
# 774  Finally chosen pathway:
# 1/1 [==============================] - 0s 41ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 58ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 48ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  19.649002079266676 , acetyl: 2.8920952799469974 , levo:  28.343989149230893
# 775  Finally chosen pathway:
# 1/1 [==============================] - 0s 48ms/step
# Transition: Cortex -> Striatum, Reward: 250.0
# 1/1 [==============================] - 0s 63ms/step
# Transition: Striatum -> GPi, Reward: -250.0
# 1/1 [==============================] - 0s 51ms/step
# Transition: GPi -> Thalamus, Reward: 800.0
#
# dopamine :  50.915330256623974 , acetyl: 1.057538862794873 , levo:  27.04255185810972
# 776  Finally chosen pathway:
# 1/1 [==============================] - 0s 42ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 55ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 49ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  116.6211281231314 , acetyl: 2.2280466035013755 , levo:  108.00220900756713
# 777  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  15.725721711665695 , acetyl: 4.534324790227483 , levo:  207.08365487479233
# 778  Finally chosen pathway:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPi, Reward: 450.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  75.0228039355739 , acetyl: 3.9718947739018065 , levo:  191.8562277125238
# 779  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPe, Reward: None
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  3.3486831459329314 , acetyl: 1.5154461296187427 , levo:  155.86153668136683
# 780  Finally chosen pathway:
# 1/1 [==============================] - 0s 44ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 34ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  24.337029067828365 , acetyl: 3.1062132987473317 , levo:  110.043982678946
# 781  Finally chosen pathway:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  130.93706067176933 , acetyl: 2.1862720821394825 , levo:  216.1418924398432
# 782  Finally chosen pathway:
# 1/1 [==============================] - 0s 59ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 58ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 62ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 57ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  125.56553553935571 , acetyl: 0.630755740972049 , levo:  142.25160329090602
# 783  Finally chosen pathway:
# 1/1 [==============================] - 0s 56ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPe -> STN, Reward: -300.0
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  111.89653350668529 , acetyl: 4.4162808707914145 , levo:  189.55866862538699
# 784  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 32ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  158.77319853957798 , acetyl: 4.631729195625464 , levo:  117.00058282844105
# 785  Finally chosen pathway:
# 1/1 [==============================] - 0s 37ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 46ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 54ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  189.68758222276594 , acetyl: 3.9274037893551395 , levo:  205.26263127299185
# 786  Finally chosen pathway:
# 1/1 [==============================] - 0s 45ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 42ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 55ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  69.92258293007389 , acetyl: 4.13409729778849 , levo:  35.04347451869835
# 787  Finally chosen pathway:
# 1/1 [==============================] - 0s 55ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 65ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 62ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 39ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 46ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  102.81374507075748 , acetyl: 4.486641462014895 , levo:  139.1162231360947
# 788  Finally chosen pathway:
# 1/1 [==============================] - 0s 56ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 54ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 45ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 44ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  161.17025556301388 , acetyl: 2.397573416011806 , levo:  184.099077045893
# 789  Finally chosen pathway:
# 1/1 [==============================] - 0s 59ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 50ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 41ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  138.8091922002965 , acetyl: 4.711367169634121 , levo:  15.015682305896338
# 790  Finally chosen pathway:
# 1/1 [==============================] - 0s 38ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 52ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 52ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  58.59808556805404 , acetyl: 2.6369542519588185 , levo:  223.8883784950674
# 791  Finally chosen pathway:
# 1/1 [==============================] - 0s 34ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# Transition: Striatum -> GPi, Reward: None
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  159.431842411781 , acetyl: 2.7536586785677373 , levo:  49.49602471097928
# 792  Finally chosen pathway:
# 1/1 [==============================] - 0s 37ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  92.30488307625433 , acetyl: 4.357861224322111 , levo:  121.99375399349354
# 793  Finally chosen pathway:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 32ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 39ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  0.4602418533009608 , acetyl: 0.9618620235853255 , levo:  15.516957077038818
# 794  Finally chosen pathway:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: None
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 32ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  135.8867969342602 , acetyl: 3.940772406485948 , levo:  209.02724303911003
# 795  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: None
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  44.6554507222914 , acetyl: 2.254589859317715 , levo:  195.79004920240857
# 796  Finally chosen pathway:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  37.42971738206622 , acetyl: 2.943296797772788 , levo:  169.99939844487903
# 797  Finally chosen pathway:
# 1/1 [==============================] - 0s 27ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPi, Reward: 450.0
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  93.4028701844405 , acetyl: 4.250842457162401 , levo:  129.26921058907598
# 798  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 58ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 43ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 41ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 37ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  74.1157849158913 , acetyl: 4.156122446801964 , levo:  123.86244450099504
# 799  Finally chosen pathway:
# 1/1 [==============================] - 0s 46ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 41ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  134.44952783378113 , acetyl: 4.867012141503574 , levo:  247.9901194868041
# 800  Finally chosen pathway:
# 1/1 [==============================] - 0s 50ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 45ms/step
# Transition: Striatum -> GPi, Reward: None
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  72.59844569548268 , acetyl: 3.2513123321250292 , levo:  83.89880005082256
# 801  Finally chosen pathway:
# 1/1 [==============================] - 0s 53ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 50ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  103.8812966019686 , acetyl: 2.7257587504044976 , levo:  229.17149676289876
# 802  Finally chosen pathway:
# 1/1 [==============================] - 0s 46ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 70ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 58ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# ...
# 982  Finally chosen pathway:
# 1/1 [==============================] - 0s 61ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 43ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 43ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 45ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  9.62270639706214 , acetyl: 0.9855343932533445 , levo:  118.74311288943743
# 983  Finally chosen pathway:
# 1/1 [==============================] - 0s 51ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 64ms/step
# Transition: Striatum -> GPe, Reward: None
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  137.46531860478257 , acetyl: 1.8028192902380866 , levo:  96.21939205031057
# 984  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  144.38981618900618 , acetyl: 2.1155812324340038 , levo:  134.99488185159817
# 985  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 32ms/step
# Transition: Striatum -> GPi, Reward: 550.0
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  36.40556179703065 , acetyl: 3.3605017689206913 , levo:  158.71603162306005
# 986  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 34ms/step
# Transition: Striatum -> GPi, Reward: 450.0
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  113.76804728254363 , acetyl: 4.956508913539352 , levo:  181.17630969143113
# 987  Finally chosen pathway:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  41.046339004241844 , acetyl: 1.1897656268533277 , levo:  64.6471456434464
# 988  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 31ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 56ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  46.30805604026459 , acetyl: 3.1450148377038274 , levo:  9.216211543635112
# 989  Finally chosen pathway:
# 1/1 [==============================] - 0s 38ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 63ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 41ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 60ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 79ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  41.14289449165137 , acetyl: 1.7657438341264806 , levo:  94.00623243028669
# 990  Finally chosen pathway:
# 1/1 [==============================] - 0s 66ms/step
# Transition: Cortex -> Striatum, Reward: -150.0
# 1/1 [==============================] - 0s 44ms/step
# Transition: Striatum -> GPe, Reward: -200.0
# 1/1 [==============================] - 0s 58ms/step
# Transition: GPe -> STN, Reward: -300.0
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# Transition: STN -> GPi, Reward: -350.0
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: 1000.0
#
# dopamine :  145.13974527087942 , acetyl: 4.892189697019106 , levo:  31.61962452946543
# 991  Finally chosen pathway:
# 1/1 [==============================] - 0s 30ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 29ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  104.23412136754872 , acetyl: 3.262427482586007 , levo:  19.658250537822386
# 992  Finally chosen pathway:
# 1/1 [==============================] - 0s 28ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 37ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 25ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  69.35345427042546 , acetyl: 4.200663691324688 , levo:  11.192619917324286
# 993  Finally chosen pathway:
# 1/1 [==============================] - 0s 29ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 34ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 29ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  168.4571918822077 , acetyl: 3.1815874521096794 , levo:  76.32869214880364
# 994  Finally chosen pathway:
# 1/1 [==============================] - 0s 39ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 33ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 33ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 43ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 35ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  114.65191300044602 , acetyl: 2.7211938033759866 , levo:  234.99602231042533
# 995  Finally chosen pathway:
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 28ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 32ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  115.07944084410752 , acetyl: 4.757404429696147 , levo:  137.74175474665782
# 996  Finally chosen pathway:
# 1/1 [==============================] - 0s 27ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 27ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 28ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  123.96697539985078 , acetyl: 3.3439008290910452 , levo:  76.2892045059999
# 997  Finally chosen pathway:
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 36ms/step
# Transition: Striatum -> GPe, Reward: None
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPe -> STN, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# Transition: STN -> GPi, Reward: None
# 1/1 [==============================] - 0s 43ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  23.339460515947767 , acetyl: 0.8292809034288222 , levo:  82.66067153519421
# 998  Finally chosen pathway:
# 1/1 [==============================] - 0s 27ms/step
# Transition: Cortex -> Striatum, Reward: None
# 1/1 [==============================] - 0s 30ms/step
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 26ms/step
# Transition: GPi -> Thalamus, Reward: None
#
# dopamine :  66.54169875265997 , acetyl: 3.9006345408666463 , levo:  37.327444639998845
# 999  Finally chosen pathway:
# 1/1 [==============================] - 0s 32ms/step
# Transition: Cortex -> Striatum, Reward: None
# Transition: Striatum -> GPi, Reward: None
# 1/1 [==============================] - 0s 31ms/step
# Transition: GPi -> Thalamus, Reward: None
# -------------------------------------------------------------
# Accuracy:  0.4854854854854855

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Define the pathways
direct_pathway_edges = [("Cortex", "Striatum"), ("Striatum", "GPi"), ("GPi", "Thalamus")]
indirect_pathway_edges = [("Cortex", "Striatum"), ("Striatum", "GPe"), ("GPe", "STN"), ("STN", "GPi"), ("GPi", "Thalamus")]
on=""

# Create a graph
G = nx.DiGraph()

# Add edges for direct pathway
G.add_edges_from(direct_pathway_edges)

# Add edges for indirect pathway
G.add_edges_from(indirect_pathway_edges)

# Testing the trained DQN agent
state = loaded_env.reset()
done = False

output_array = [state]

dopamine_value = np.random.uniform(0,196)
acetyl_value = np.random.uniform(0,5)
levodopa_value = np.random.uniform(0,250)
print("\ndopamine : ", dopamine_value)

while not done:
    # Convert state to its corresponding index
    state_index = loaded_env.states.index(state)

    action = loaded_agent.select_action(state_index)

    # making sure only existing actions are taken.
    while ((loaded_env.actions[action] not in loaded_env.transition_probs[state])):
            action = loaded_agent.select_action(state_index)

    next_state, reward, done, _ = loaded_env.step(
            loaded_env.actions[action], dopamine_value, acetyl_value, levodopa_value)
    #print(f"Transition: {env.states[state_index]} -> {next_state}, Reward: {reward}")

    output_array.append(next_state)

    state = next_state

# Create a directed graph
output_graph = nx.DiGraph()

# Add nodes and edges based on the output array
for i in range(len(output_array) - 1):
    output_graph.add_edge(output_array[i], output_array[i+1])

# Check conditions and visualize the graph accordingly
if dopamine_value < 39.5:
    if output_array == indirect_array:
        on="1"
        plt.title("Indirect Pathway")
        nx.draw(output_graph, with_labels=True, node_size=2500, node_color="white", edgecolors="black", linewidths=1.5, font_size=10, font_weight="bold", arrowsize=20)
    else:
        print("Pathway not found.")

elif dopamine_value > 39.6 and dopamine_value < 195.8:
    if output_array == direct_array:
        om="0"
        plt.title("Direct Pathway")
        nx.draw(output_graph,with_labels=True, node_size=2500, node_color="white", edgecolors="black", linewidths=1.5, font_size=10, font_weight="bold", arrowsize=20)
    else:
        print("Pathway not found.")

plt.show()
# Out:
# dopamine :  42.85597463437375

# %%
import pandas as pd

# Read the text file into a DataFrame
df_pd = pd.read_csv('/content/drive/MyDrive/BASAL/dummyGeneActiveData_Day1.txt', delimiter='\t')
df_nonpd = pd.read_csv("/content/drive/MyDrive/BASAL/dummyPebbleData_Day1.txt", delimiter="\t")

# Calculate the average for each column
average_values_pd = df_pd.mean()
average_values_nonpd = df_nonpd.mean()

# Display the average values
print("Average values:")
print(average_values_nonpd)
# Out:
# Average values:
# timestamp           1.429522e+09
# Pebble_X           -5.528709e-01
# Pebble_Y            1.485991e-01
# Pebble_Z           -9.669751e+00
# Pebble_Magnitude    9.692960e+00
# dtype: float64

# %%
# final ouput from the model
if(output_array == indirect_array):
  print(f"x: {average_values_pd[1]}, y: {average_values_pd[2]}, z: {average_values_pd[3]}")
elif(output_array == direct_array):
  print(f"x: {average_values_nonpd[1]}, y: {average_values_nonpd[2]}, z: {average_values_nonpd[3]}")
# Out:
# x: -0.5528708847336269, y: 0.1485990549217123, z: -9.669750824849604
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
